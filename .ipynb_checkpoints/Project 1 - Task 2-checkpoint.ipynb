# %%
import pandas as pd
import numpy as np

# %%
app_data = pd.read_json("package_info.json")

# %%
app_data
# Out:
#      app_name                                    app_description  \
# 0        a2ps                           Any-to-PostScript filter
# 1      a52dec  Library for decoding ATSC A/52 streams (AKA 'A...
# 2     aacgain                  AAC-supporting version of mp3gain
# 3       aalib                Portable ASCII art graphics library
# 4      aamath      Renders mathematical expressions as ASCII art
# ...       ...                                                ...
# 5756     zxcc  CP/M 2/3 emulator for cross-compiling and CP/M...
# 5757    zydis  Fast and lightweight x86/x86_64 disassembler l...
# 5758     zyre  Local Area Clustering for Peer-to-Peer Applica...
# 5759     zzuf               Transparent application input fuzzer
# 5760      zzz             Command-line tool to put Macs to sleep
#
#                                          app_installs
# 0      {'30days': 87, '90days': 295, '365days': 1114}
# 1        {'30days': 17, '90days': 68, '365days': 413}
# 2       {'30days': 50, '90days': 135, '365days': 603}
# 3     {'30days': 119, '90days': 358, '365days': 1860}
# 4        {'30days': 32, '90days': 56, '365days': 183}
# ...                                               ...
# 5756       {'30days': 0, '90days': 10, '365days': 30}
# 5757        {'30days': 1, '90days': 3, '365days': 19}
# 5758        {'30days': 2, '90days': 8, '365days': 71}
# 5759        {'30days': 5, '90days': 9, '365days': 51}
# 5760     {'30days': 20, '90days': 73, '365days': 361}
#
# [5761 rows x 3 columns]

# %%
# Pulling and adding 3 columns to the app_data Dataframe
app_installs_30d = []
app_installs_90d = []
app_installs_365d = []
for x in app_data['app_installs']:
    app_installs_30d.append(x['30days'])
    app_installs_90d.append(x['90days'])
    app_installs_365d.append(x['365days'])
app_data['app_installs_30d'] = app_installs_30d
app_data['app_installs_90d'] = app_installs_90d
app_data['app_installs_365d'] = app_installs_365d

# %%
app_data # app_data dataframe with new columns added
# Out:
#      app_name                                    app_description  \
# 0        a2ps                           Any-to-PostScript filter
# 1      a52dec  Library for decoding ATSC A/52 streams (AKA 'A...
# 2     aacgain                  AAC-supporting version of mp3gain
# 3       aalib                Portable ASCII art graphics library
# 4      aamath      Renders mathematical expressions as ASCII art
# ...       ...                                                ...
# 5756     zxcc  CP/M 2/3 emulator for cross-compiling and CP/M...
# 5757    zydis  Fast and lightweight x86/x86_64 disassembler l...
# 5758     zyre  Local Area Clustering for Peer-to-Peer Applica...
# 5759     zzuf               Transparent application input fuzzer
# 5760      zzz             Command-line tool to put Macs to sleep
#
#                                          app_installs  app_installs_30d  \
# 0      {'30days': 87, '90days': 295, '365days': 1114}                87
# 1        {'30days': 17, '90days': 68, '365days': 413}                17
# 2       {'30days': 50, '90days': 135, '365days': 603}                50
# 3     {'30days': 119, '90days': 358, '365days': 1860}               119
# 4        {'30days': 32, '90days': 56, '365days': 183}                32
# ...                                               ...               ...
# 5756       {'30days': 0, '90days': 10, '365days': 30}                 0
# 5757        {'30days': 1, '90days': 3, '365days': 19}                 1
# 5758        {'30days': 2, '90days': 8, '365days': 71}                 2
# 5759        {'30days': 5, '90days': 9, '365days': 51}                 5
# 5760     {'30days': 20, '90days': 73, '365days': 361}                20
#
#       app_installs_90d  app_installs_365d
# 0                  295               1114
# 1                   68                413
# 2                  135                603
# 3                  358               1860
# 4                   56                183
# ...                ...                ...
# 5756                10                 30
# 5757                 3                 19
# 5758                 8                 71
# 5759                 9                 51
# 5760                73                361
#
# [5761 rows x 6 columns]

# %%
# pull only top 10 values from the app_data for 30days, 90 days, and 365days install. 
# Create new Dataframe
#df_30days_installs_10apps

df_30days_installs_10apps = app_data.sort_values('app_installs_30d', ascending=False).iloc[0:10]
df_90days_installs_10apps = app_data.sort_values('app_installs_90d', ascending=False).iloc[0:10]
df_365days_installs_10apps = app_data.sort_values('app_installs_365d', ascending=False).iloc[0:10]

# %%
df_30days_installs_10apps.to_csv('Top 30days Installs', index=False)

# %%
df_90days_installs_10apps.to_csv('Top 90days Installs', index=False)

# %%
df_365days_installs_10apps.to_csv('Top 365days Installs', index=False)

# %%
df_30days_installs_10apps.to_json('Top 30days Installs in JSON')

# %%
df_90days_installs_10apps.to_json('Top 90days Installs in JSON')

# %%
df_365days_installs_10apps.to_json('Top 365days Installs in JSON')

# %%
#pd.read_json('Top 30days Installs in JSON')
